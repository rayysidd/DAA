# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
    {'bubble': 2, 'selection': 1, 'insertion': 1, 'tournament': 0},
    {'bubble': 41, 'selection': 26, 'insertion': 12, 'tournament': 1},
    {'bubble': 7071, 'selection': 2691, 'insertion': 1342, 'tournament': 8}
]
labels = ['1000', '10000', '100000']

# %%
df = pd.DataFrame(data,index=labels)

# %%
df
# Out:
#         bubble  selection  insertion  tournament
# 1000         2          1          1           0
# 10000       41         26         12           1
# 100000    7071       2691       1342           8

# %%
df.iloc[0:2].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[2:3].plot(kind='bar')
# Out:
# <Axes: >
