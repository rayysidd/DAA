# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
       {'Linear':7084,'Binary':1709},
       {'Linear':56042,'Binary':1125},
       {'Linear':545333,'Binary':1500}
]
labels = ['500','5000','50000']

# %%
df = pd.DataFrame(data,index=labels)

# %%
df
# Out:
#        Linear  Binary
# 500      7084    1709
# 5000    56042    1125
# 50000  545333    1500

# %%
df.iloc[0].plot(kind='bar')
plt.xlabel('Algorithm')
plt.ylabel('Time in ns')
# Out:
# Text(0, 0.5, 'Time in ns')

# %%
df.iloc[1].plot(kind='bar')
plt.xlabel('Algorithm')
plt.ylabel('Time in ns')
# Out:
# Text(0, 0.5, 'Time in ns')

# %%
df.iloc[2].plot(kind='bar')
plt.xlabel('Algorithm')
plt.ylabel('Time in ns')
# Out:
# Text(0, 0.5, 'Time in ns')
