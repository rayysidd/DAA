# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
    {'naive':0.00675 , 'rabin': 0.00785 , 'kmp': 0.00568, 'finite': 0.00147},
]

# %%
df = pd.DataFrame(data)

# %%
df.plot(kind='bar')
plt.xlabel('Algorithm')
plt.ylabel('Time (seconds)')
plt.title('Algorithm Performance')
plt.show()
