# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
    {'naive':18401000 , 'rabin': 17966000 , 'kmp': 17101100, 'finite': 4870800},
]

# %%
df = pd.DataFrame(data)

# %%
df.plot(kind='bar')
plt.xlabel('Algorithm')
plt.ylabel('Time (seconds)')
plt.title('Algorithm Performance')
plt.show()
